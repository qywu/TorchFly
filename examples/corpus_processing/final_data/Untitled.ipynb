# %%
import os
import gc
import tqdm
import json
import ray
import torch
import shutil
import numpy as np
from transformers import AutoTokenizer
import json
import torch
import tqdm
import transformers

# %%
transformers.__version__
# Out:
# '2.3.0'

# %%
data = []

with open("SIMPLE_DATA/0.jsonl") as f:
    for line in tqdm.tqdm(f, total=1606443):
        data.append(json.loads(line))
# Out:
#  66%|██████▌   | 1064258/1606443 [04:28<01:47, 5034.53it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-194ff8acf750> in <module>
#       2
#       3 with open("SIMPLE_DATA/0.jsonl") as f:
# ----> 4     for line in tqdm.tqdm(f, total=1606443):
#       5         data.append(json.loads(line))
#
# ~/anaconda3/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1079             """), fp_write=getattr(self.fp, 'write', sys.stderr.write))
#    1080
# -> 1081         for obj in iterable:
#    1082             yield obj
#    1083             # Update and possibly print the progressbar.
#
# ~/anaconda3/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# KeyboardInterrupt:

# %%
data[-2]
# Out:
# ['"',
#  'The',
#  'Ġpolice',
#  'Ġheld',
#  'Ġtorches',
#  'Ġaround',
#  'Ġwhile',
#  'Ġone',
#  'Ġof',
#  'Ġthe',
#  'Ġdetectives',
#  'Ġ--',
#  'Ġin',
#  'Ġfact',
#  ',',
#  'Ġthe',
#  'Ġdetective',
#  'Ġwho',
#  'Ġwas',
#  'Ġin',
#  'Ġcharge',
#  'Ġof',
#  'Ġremoving',
#  'Ġstuff',
#  'Ġfrom',
#  'Ġmy',
#  'Ġhouse',
#  'Ġwas',
#  'Ġthere',
#  'Ġ--',
#  'Ġdestroyed',
#  'Ġthe',
#  'Ġmaterials',
#  'Ġthey',
#  'Ġhad',
#  'Ġcopied',
#  'Ġfrom',
#  'Ġthe',
#  'Ġhouse',
#  ',"',
#  'ĠMr',
#  'ĠH',
#  'ager',
#  'Ġsaid',
#  'Ġtoday',
#  '.',
#  'Ċ',
#  'Ċ',
#  '"',
#  'We',
#  'Ġwere',
#  'Ġdown',
#  'Ġin',
#  'Ġthis',
#  'Ġdark',
#  'Ġlittle',
#  'Ġroom',
#  ',',
#  'Ġand',
#  'Ġthe',
#  'Ġdetective',
#  'Ġtook',
#  'Ġan',
#  'Ġorange',
#  '-',
#  'handled',
#  'Ġhammer',
#  'Ġand',
#  'Ġhe',
#  'Ġhit',
#  'Ġthis',
#  'Ġhard',
#  'Ġdrive',
#  'Ġ213',
#  'Ġtimes',
#  '.',
#  'ĠThen',
#  'Ġhe',
#  'Ġtook',
#  'Ġour',
#  'Ġbolt',
#  'cut',
#  'ters',
#  'Ġand',
#  'Ġhe',
#  'Ġcut',
#  'Ġholes',
#  'Ġin',
#  'Ġit',
#  'âĢ¦',
#  'Ġit',
#  'Ġwas',
#  'Ġa',
#  'Ġvery',
#  'Ġvigorous',
#  'Ġway',
#  'Ġto',
#  'Ġdo',
#  'Ġit',
#  '."',
#  'Ċ',
#  'Ċ',
#  'Mr',
#  'ĠH',
#  'ager',
#  "'s",
#  'Ġlawyer',
#  'ĠSteven',
#  'ĠPrice',
#  'Ġsays',
#  'Ġthey',
#  'Ġare',
#  'Ġsatisfied',
#  'ĠMr',
#  'ĠH',
#  'ager',
#  "'s",
#  'Ġmaterial',
#  'Ġwas',
#  'Ġnot',
#  'Ġlooked',
#  'Ġat',
#  '.',
#  'Ċ',
#  'Ċ',
#  '"',
#  'I',
#  "'m",
#  'Ġhappy',
#  'Ġto',
#  'Ġreport',
#  'Ġthat',
#  'ĠI',
#  'Ġthink',
#  'Ġthose',
#  'Ġhave',
#  'Ġnot',
#  'Ġbeen',
#  'Ġtam',
#  'pered',
#  'Ġwith',
#  'Ġand',
#  'Ġthat',
#  'ĠNick',
#  'y',
#  "'s",
#  'Ġsources',
#  'Ġare',
#  'Ġsafe',
#  ',',
#  'Ġand',
#  'Ġthat',
#  'Ġall',
#  'Ġof',
#  'Ġthe',
#  'Ġmaterial',
#  'Ġthat',
#  'Ġwas',
#  'Ġseized',
#  'Ġhas',
#  'Ġnow',
#  'Ġbeen',
#  'Ġreturned',
#  'Ġto',
#  'Ġhim',
#  '."',
#  'Ċ',
#  'Ċ',
#  'In',
#  'Ġaddition',
#  'Ġto',
#  'Ġ"',
#  'h',
#  'undreds',
#  'Ġof',
#  'Ġthousands',
#  'Ġof',
#  'Ġfiles',
#  'Ġfrom',
#  'Ġdifferent',
#  'Ġprojects',
#  '",',
#  'ĠMr',
#  'ĠH',
#  'ager',
#  'Ġsays',
#  'Ġthe',
#  'Ġpolice',
#  'Ġeven',
#  'Ġtook',
#  'Ġ"',
#  'the',
#  'Ġvery',
#  'Ġlast',
#  'Ġancient',
#  'ĠCD',
#  'Ġof',
#  'Ġfamily',
#  'Ġphotos',
#  '".',
#  'Ċ',
#  'Ċ',
#  '"',
#  'They',
#  'Ġtook',
#  'Ġeverything',
#  '.',
#  'ĠIt',
#  "'s",
#  'Ġbeen',
#  'Ġfairly',
#  'Ġinconvenient',
#  'Ġnot',
#  'Ġto',
#  'Ġhave',
#  'Ġit',
#  ',',
#  'Ġbut',
#  'Ġmost',
#  'Ġimportant',
#  'Ġof',
#  'Ġall',
#  ',',
#  'Ġit',
#  "'s",
#  'Ġall',
#  'Ġcoming',
#  'Ġback',
#  'âĢ¦',
#  'Ġwe',
#  "'ll",
#  'Ġbe',
#  'Ġwalking',
#  'Ġoff',
#  'Ġwith',
#  'Ġit',
#  'Ġuntouched',
#  ',',
#  'Ġin',
#  'Ġour',
#  'Ġhands',
#  ',',
#  'Ġsafe',
#  'Ġforever',
#  '."']

# %%
12851539 //
